# %% [markdown]
# # Demonstrating unified Citrine/MDF upload

# %% [markdown]
# ## Unified metadata format
#
# We have defined a unified metadata schema for the domain-generic metadata, e.g. authors, licenses, reference, and contact information.  This is implemented in the [`matmeta`](https://github.com/MaterialsDataInfrastructureConsortium/CommonMetadata) package, which is published on `pypi`.

# %% [markdown]
# First, let's ask `matmeta` what we need:

# %%
from matmeta.payload_metaclass import get_common_payload_template
import json
print(json.dumps(get_common_payload_template(), indent=2))
# Out:
# {
#   "all_fields": {
#     "title": "string",
#     "source": {
#       "name": "string",
#       "producer": "string",
#       "url": "url string",
#       "tags": [
#         "string"
#       ]
#     },
#     "data_contacts": [
#       {
#         "given_name": "string",
#         "family_name": "string",
#         "title": "string",
#         "orcid": "TBD",
#         "email": "string",
#         "tags": [
#           "string"
#         ]
#       }
#     ],
#     "data_contributors": [
#       {
#         "given_name": "string",
#         "family_name": "string",
#         "title": "string",
#         "orcid": "TBD",
#         "email": "string",
#         "tags": [
#           "string"
#         ]
#       }
#     ],
#     "links": {
#       "landing_page": "uri (string)",
#       "publication": [
#         "uri (string)"
#       ],
#       "data_doi": "uri (string)",
#       "related_id": [
#         "string"
#       ],
#       "parent_id": "string"
#     },
#     "authors": [
#       {
#         "given_name": "string",
#         "family_name": "string",
#         "title": "string",
#         "orcid": "TBD",
#         "email": "string",
#         "tags": [
#           "string"
#         ]
#       }
#     ],
#     "licenses": [
#       {
#         "name": "string",
#         "description": "string",
#         "url": "string",
#         "tags": [
#           "string"
#         ]
#       }
#     ],
#     "citations": [
#       {
#         "authors": [
#           {
#             "given_name": "string",
#             "family_name": "string",
#             "title": "string",
#             "orcid": "TBD",
#             "email": "string",
#             "tags": [
#               "string"
#             ]
#           }
#         ],
#         "year": "string",
#         "title": "string",
#         "journal": "string",
#         "volume": "string",
#         "issue": "string",
#         "page_location": "string",
#         "edition": "string",
#         "publication_location": "string",
#         "publisher": "string",
#         "extent": "string",
#         "notes": "string"
#       }
#     ],
#     "repository": "not yet available",
#     "collection": "not yet available",
#     "tags": [
#       "string"
#     ],
#     "description": "string",
#     "raw": "not yet available",
#     "year": "integer",
#     "composition": "not yet available"
#   },
#   "required_fields": {
#     "title": "string",
#     "source": {
#       "name": "string"
#     },
#     "data_contacts": [
#       {
#         "given_name": "string",
#         "family_name": "string",
#         "email": "string"
#       }
#     ],
#     "data_contributors": [
#       {
#         "given_name": "string",
#         "family_name": "string",
#         "email": "string"
#       }
#     ],
#     "links": {
#       "landing_page": "uri (string)"
#     },
#     "description": "string"
#   },
#   "usage": "payload = <service class, e.g. CITPayload>(**input_dictionary).metapayload"
# }

# %% [markdown]
# ## Example: Alloy Database (from Prof. Mike Widom @ CMU)
#
# We found a database that wasn't already on MDF or Citrination.  Here is the common metadata.

# %%
metadata = {
    "title": "Alloy Database (data)", 
    "source": {
        "name": "Alloy Database",
        "producer": "Alloy Database",
        "url": "http://alloy.phys.cmu.edu/",
        "tags": [ 
            "Allow Database",
            "VASP",
        ]
    },
    "data_contacts": [
        {
            "given_name": "Marek",
            "family_name": "Mihalkovic",
            "title": "independent researcher",
            "email": "marek.mihalkovic@savba.sk"
        },
        {
            "given_name": "Michael",
            "family_name": "Widom",
            "title": "Professor of Physics",
            "email": "widom@cmu.edu"
        }
    ],
    "data_contributors": [
        {
            "given_name": "Qin",
            "family_name": "Gao",
            "title": "Graduate Student"
        },
        {
            "given_name": "Sanxi",
            "family_name": "Yao",
            "title": "Graduate Student"
        },
        {
            "given_name": "Will",
            "family_name": "Huhn",
            "title": "Graduate Student"
        },
    ],
    "links": {
        "landing_page": "http://alloy.phys.cmu.edu/"
    },
    "authors": [
        {
            "given_name": "Marek",
            "family_name": "Mihalkovic",
            "title": "independent researcher",
            "email": "marek.mihalkovic@savba.sk"
        },
        {
            "given_name": "Michael",
            "family_name": "Widom",
            "title": "Professor of Physics",
            "email": "widom@cmu.edu"
        },
        {
            "given_name": "Qin",
            "family_name": "Gao",
            "title": "Graduate Student"
        },
        {
            "given_name": "Sanxi",
            "family_name": "Yao",
            "title": "Graduate Student"
        },
        {
            "given_name": "Will",
            "family_name": "Huhn",
            "title": "Graduate Student"
        }
    ],
    "licenses": [
        {
            "name": "Creative Commons",
            "description": "Attribution 4.0 International (CC BY 4.0)",
            "url": "https://creativecommons.org/licenses/by/4.0/"
        }
    ],
    "description": "Welcome to the alloy structure and cohesive energy database. You can find structures and enthalpy of formation data for stable and metastable structures of many alloy systems*.",
    "year": "2011"
}
with open("data/B/metadata.json", "w") as f:
    json.dump(metadata, f)

# %% [markdown]
# As a simple example, we upload calculations of boron's structure to MDF's testing collection and a dataset on Citrination.

# %%
from pif_ingestor import main as pif_ingestor_driver
from pif_ingestor.ui import get_cli
command = "data/B dft -r -m data/B/metadata.json -d 150799 --globus-collection=35".split()
args = get_cli().parse_args(args=command)

pif_ingestor_driver(args)
# Out:
# WARNING:root:Failed to load 'ebsd = ebsd_converter.converter' due to No module named 'ebsd_converter'
# Multiple endpoints found:
# 1 :  Helm 	 1ba4b688-9a0f-11e7-ac6f-22000a92523b
# 2 :  None 	 e4c16f22-6d04-11e5-ba46-22000b92c6ec
#
# Please choose the endpoint on this machine
# Enter the number of the correct endpoint (-1 to cancel): 1
# Do you accept the license for collection 35? y/n: y
# {
#   "globus_info": {
#     "globus.shared_endpoint.path": "/mdf-test2/unpublished/publication_690/",
#     "dc.description.provenance": "Submitted by Max Hutchinson (maxhutch@uchicago.edu) on 2017-09-15T15:00:10Z",
#     "globus.shared_endpoint.name": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec",
#     "id": 690
#   },
#   "data/B/metadata.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/metadata.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/metadata.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/metadata.json"
#   },
#   "data/B/ingestor.log": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/ingestor.log",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/ingestor.log",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/ingestor.log"
#   },
#   "data/B/B6O.hR14/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/OUTCAR"
#   },
#   "data/B/B6O.hR14/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/INCAR"
#   },
#   "data/B/B6O.hR14/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/pif.json"
#   },
#   "data/B/B6O.hR14/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B6O.hR14/POSCAR"
#   },
#   "data/B/B13C2.hR15/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/OUTCAR"
#   },
#   "data/B/B13C2.hR15/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/INCAR"
#   },
#   "data/B/B13C2.hR15/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/pif.json"
#   },
#   "data/B/B13C2.hR15/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B13C2.hR15/POSCAR"
#   },
#   "data/B/B.tP58/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP58/OUTCAR"
#   },
#   "data/B/B.tP58/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP58/INCAR"
#   },
#   "data/B/B.tP58/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP58/pif.json"
#   },
#   "data/B/B.tP58/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP58/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP58/POSCAR"
#   },
#   "data/B/B.tP196/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP196/OUTCAR"
#   },
#   "data/B/B.tP196/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP196/INCAR"
#   },
#   "data/B/B.tP196/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP196/pif.json"
#   },
#   "data/B/B.tP196/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.tP196/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.tP196/POSCAR"
#   },
#   "data/B/B.oP28/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.oP28/OUTCAR"
#   },
#   "data/B/B.oP28/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.oP28/INCAR"
#   },
#   "data/B/B.oP28/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.oP28/pif.json"
#   },
#   "data/B/B.oP28/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.oP28/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.oP28/POSCAR"
#   },
#   "data/B/B.hR141-opt/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/OUTCAR"
#   },
#   "data/B/B.hR141-opt/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/INCAR"
#   },
#   "data/B/B.hR141-opt/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/pif.json"
#   },
#   "data/B/B.hR141-opt/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR141-opt/POSCAR"
#   },
#   "data/B/B.hR105/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR105/OUTCAR"
#   },
#   "data/B/B.hR105/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR105/INCAR"
#   },
#   "data/B/B.hR105/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR105/pif.json"
#   },
#   "data/B/B.hR105/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR105/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR105/POSCAR"
#   },
#   "data/B/B.hR12/OUTCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/OUTCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/OUTCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR12/OUTCAR"
#   },
#   "data/B/B.hR12/INCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/INCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/INCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR12/INCAR"
#   },
#   "data/B/B.hR12/pif.json": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/pif.json",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/pif.json",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR12/pif.json"
#   },
#   "data/B/B.hR12/POSCAR": {
#     "globus_url": "82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/POSCAR",
#     "webapp_url": "https://www.globus.org/app/transfer?origin_id=82f1b5c6-6e9b-11e5-ba47-22000b92c6ec&origin_path=/mdf-test2/unpublished/publication_690/data/data/B/B.hR12/POSCAR",
#     "http_url": "https://data.materialsdatafacility.org//mdf-test2/unpublished/publication_690/data/data/B/B.hR12/POSCAR"
#   }
# }
